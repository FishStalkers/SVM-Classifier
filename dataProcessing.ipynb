# %%
import pandas as pd

# %%
df = pd.read_csv("scRNAseq_Benchmark_datasets/Inter-dataset/Brain/MouseALM_HumanMTG/MouseALM_HumanMTG.csv")

# %%
df.head()
# Out:
#             Unnamed: 0  X0610007P14Rik  X0610009O20Rik  X0610010F05Rik  \
# 0  F1S4_180124_314_A01              80              11             135
# 1  F1S4_180124_315_A01             233              37             183
# 2  F1S4_180124_315_B01             142               4             129
# 3  F1S4_180124_315_C01              54               1              28
# 4  F1S4_180124_315_D01             139               0              22
#
#    X0610011F06Rik  X0610030E20Rik  X0610037L13Rik  X0610040J01Rik  \
# 0              32               0              31               1
# 1             114               0             189               0
# 2               9              14              73               0
# 3              40              17              67               0
# 4             117              10             105               0
#
#    X1110001J03Rik  X1110004E09Rik  ...  Zwint  Zxdb  Zxdc  Zyg11a  Zyg11b  \
# ...

# %%
df.shape
# Out:
# (22183, 16069)
